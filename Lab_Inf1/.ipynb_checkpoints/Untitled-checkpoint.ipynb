# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('data_of_sort_equal.csv',header=None)
data
# Out:
#                0      1         2
# 0      heap_sort    100  0.000020
# 1      heap_sort    100  0.000018
# 2      heap_sort    100  0.000018
# 3      heap_sort    100  0.000018
# 4      heap_sort    100  0.000018
# ...          ...    ...       ...
# 79995   put_sort  10000  0.135087
# 79996   put_sort  10000  0.133544
# 79997   put_sort  10000  0.139265
# 79998   put_sort  10000  0.139345
# 79999   put_sort  10000  0.146769
#
# [80000 rows x 3 columns]

# %%
dt={}
for nm in set(data[0]):
    dt[nm]={'N':[],'T':[]}
for i in range(data.shape[0]):
    #dt.append({'index':i,data[0][i]:{'N':data[1][i], 'T':data[2][i]}})
    dt[data[0][i]]['N'].append(data[1][i])
    dt[data[0][i]]['T'].append(data[2][i])
for nm in set(data[0]):
    dt[nm]=pd.DataFrame(dt[nm])
dt
# Out:
# {'buble_sort':           N         T
#  0       100  0.000063
#  1       100  0.000091
#  2       100  0.000076
#  3       100  0.000064
#  4       100  0.000043
#  ...     ...       ...
#  9995  10000  0.531511
#  9996  10000  0.528199
#  9997  10000  0.538694
#  9998  10000  0.553424
#  9999  10000  0.563708
#
#  [10000 rows x 2 columns],
#  'merge_sort':           N         T
#  0       100  0.000015
#  1       100  0.000043
#  2       100  0.000008
#  3       100  0.000008
#  4       100  0.000008
#  ...     ...       ...
#  9995  10000  0.001490
#  9996  10000  0.001505
#  9997  10000  0.001501
#  9998  10000  0.001648
#  9999  10000  0.001539
#
#  [10000 rows x 2 columns],
#  'choose_sort':           N         T
#  0       100  0.000074
#  1       100  0.000075
#  2       100  0.000088
#  3       100  0.000063
#  4       100  0.000061
#  ...     ...       ...
#  9995  10000  0.486132
#  9996  10000  0.496628
#  9997  10000  0.478405
#  9998  10000  0.510159
#  9999  10000  0.523119
#
#  [10000 rows x 2 columns],
#  'heap_sort':           N         T
#  0       100  0.000020
#  1       100  0.000018
#  2       100  0.000018
#  3       100  0.000018
#  4       100  0.000018
#  ...     ...       ...
#  9995  10000  0.004038
#  9996  10000  0.003714
#  9997  10000  0.003720
#  9998  10000  0.003754
#  9999  10000  0.003767
#
#  [10000 rows x 2 columns],
#  'comb_sort':           N         T
#  0       100  0.000031
#  1       100  0.000028
#  2       100  0.000065
#  3       100  0.000023
#  4       100  0.000048
#  ...     ...       ...
#  9995  10000  0.296977
#  9996  10000  0.282335
#  9997  10000  0.286087
#  9998  10000  0.269780
#  9999  10000  0.296000
#
#  [10000 rows x 2 columns],
#  'quick_sort':           N         T
#  0       100  0.000010
#  1       100  0.000008
#  2       100  0.000008
#  3       100  0.000008
#  4       100  0.000008
#  ...     ...       ...
#  9995  10000  0.001586
#  9996  10000  0.001658
#  9997  10000  0.001637
#  9998  10000  0.001679
#  9999  10000  0.001653
#
#  [10000 rows x 2 columns],
#  'shaker_sort':           N         T
#  0       100  0.000065
#  1       100  0.000073
#  2       100  0.000092
#  3       100  0.000076
#  4       100  0.000057
#  ...     ...       ...
#  9995  10000  0.427590
#  9996  10000  0.427772
#  9997  10000  0.440341
#  9998  10000  0.456896
#  9999  10000  0.432305
#
#  [10000 rows x 2 columns],
#  'put_sort':           N         T
#  0       100  0.000019
#  1       100  0.000018
#  2       100  0.000055
#  3       100  0.000036
#  4       100  0.000036
#  ...     ...       ...
#  9995  10000  0.135087
#  9996  10000  0.133544
#  9997  10000  0.139265
#  9998  10000  0.139345
#  9999  10000  0.146769
#
#  [10000 rows x 2 columns]}

# %%
datan=pd.concat(dt, axis=1,names=["sort", "data"])
datan
# Out:
# sort buble_sort           merge_sort           choose_sort            \
# data          N         T          N         T           N         T
# 0           100  0.000063        100  0.000015         100  0.000074
# 1           100  0.000091        100  0.000043         100  0.000075
# 2           100  0.000076        100  0.000008         100  0.000088
# 3           100  0.000064        100  0.000008         100  0.000063
# 4           100  0.000043        100  0.000008         100  0.000061
# ...         ...       ...        ...       ...         ...       ...
# 9995      10000  0.531511      10000  0.001490       10000  0.486132
# 9996      10000  0.528199      10000  0.001505       10000  0.496628
# 9997      10000  0.538694      10000  0.001501       10000  0.478405
# 9998      10000  0.553424      10000  0.001648       10000  0.510159
# 9999      10000  0.563708      10000  0.001539       10000  0.523119
#
# sort heap_sort           comb_sort           quick_sort           shaker_sort  \
# data         N         T         N         T          N         T           N
# 0          100  0.000020       100  0.000031        100  0.000010         100
# 1          100  0.000018       100  0.000028        100  0.000008         100
# 2          100  0.000018       100  0.000065        100  0.000008         100
# 3          100  0.000018       100  0.000023        100  0.000008         100
# 4          100  0.000018       100  0.000048        100  0.000008         100
# ...        ...       ...       ...       ...        ...       ...         ...
# 9995     10000  0.004038     10000  0.296977      10000  0.001586       10000
# 9996     10000  0.003714     10000  0.282335      10000  0.001658       10000
# 9997     10000  0.003720     10000  0.286087      10000  0.001637       10000
# 9998     10000  0.003754     10000  0.269780      10000  0.001679       10000
# 9999     10000  0.003767     10000  0.296000      10000  0.001653       10000
#
# sort           put_sort
# data         T        N         T
# 0     0.000065      100  0.000019
# 1     0.000073      100  0.000018
# 2     0.000092      100  0.000055
# 3     0.000076      100  0.000036
# 4     0.000057      100  0.000036
# ...        ...      ...       ...
# 9995  0.427590    10000  0.135087
# 9996  0.427772    10000  0.133544
# 9997  0.440341    10000  0.139265
# 9998  0.456896    10000  0.139345
# 9999  0.432305    10000  0.146769
#
# [10000 rows x 16 columns]

# %%
import seaborn as sns

# %%
data=pd.read_csv('data_of_sort_equal.csv',header=None,names=['sort','N','T, c'])
g = sns.FacetGrid(data, col="sort",col_wrap=4, margin_titles=True)
g.map(sns.regplot, "N", "T, c", color=".3",order=2,ci=99, marker="x", line_kws=dict(color="r"),)

# %%
data=pd.read_csv('data_of_sort_stan_2.csv',header=None,names=['sort','N','T, c'])
set(data['sort'])
# Out:
# {'buble_sort',
#  'choose_sort',
#  'comb_sort',
#  'heap_sort',
#  'merge_sort',
#  'put_sort',
#  'quick_sort',
#  'shaker_sort'}

# %%
data=pd.read_csv('data_of_sort_stan_2.csv',header=None,names=['sort','N','T, c'])

n2sort=['buble_sort','choose_sort','comb_sort','put_sort','shaker_sort']
data=(data.query("sort in ['buble_sort','choose_sort','comb_sort','put_sort','shaker_sort']"))
data['N']=np.log(data['N'])
data['T, c']=np.log(data['T, c'])
g = sns.FacetGrid(data, col="sort",col_wrap=3, margin_titles=True)
g.map(sns.regplot, "N", "T, c", color=".3",order=1,ci=99, marker="x", line_kws=dict(color="r"))
g.set(xlabel='Log N', ylabel='Log T')

# %%
data=pd.read_csv('data_of_sort.csv',header=None,names=['sort','N','T, c'])
n2sort=['buble_sort','choose_sort','comb_sort','put_sort','shaker_sort']
data=(data.query("sort not in ['buble_sort','choose_sort','comb_sort','put_sort','shaker_sort']"))
data['T, c']=data['T, c']/data['N']
data['N']=np.log(data['N'])
g = sns.FacetGrid(data, col="sort",col_wrap=3, margin_titles=True)
g.map(sns.regplot, "N", "T, c", color=".3",order=1,ci=99, marker="x", line_kws=dict(color="r"))
g.set(xlabel='Log N', ylabel='T/N')

# %%
n2sort=['buble_sort','choose_sort','comb_sort','put_sort','shaker_sort']
def get_dt(s):
    data__=pd.read_csv(s,header=None,names=['sort','N','T, c'])
    print(data__)
    data__=(data.query("sort == 'put_sort'"))#"sort not in ['buble_sort','choose_sort','comb_sort','put_sort','shaker_sort']"
    print(data__)
    return data__

dat_s=get_dt('data_of_sort_sorted.csv')
dat_r=get_dt('data_of_sort_reverse.csv')
dat_e=get_dt('data_of_sort_equal.csv')
dat_s
# Out:
#             sort      N      T, c
# 0      heap_sort   2000  0.000600
# 1      heap_sort   2000  0.000607
# 2      heap_sort   2000  0.000604
# 3      heap_sort   2000  0.000610
# 4      heap_sort   2000  0.000605
# ...          ...    ...       ...
# 79995   put_sort  10000  0.154208
# 79996   put_sort  10000  0.169554
# 79997   put_sort  10000  0.168814
# 79998   put_sort  10000  0.161418
# 79999   put_sort  10000  0.161268
#
# [80000 rows x 3 columns]
#             sort      N      T, c
# 0      heap_sort   2000  0.000562
# 1      heap_sort   2000  0.000539
# 2      heap_sort   2000  0.000604
# 3      heap_sort   2000  0.000619
# 4      heap_sort   2000  0.000806
# ...          ...    ...       ...
# 79995   put_sort  10000  0.129645
# 79996   put_sort  10000  0.137763
# 79997   put_sort  10000  0.128001
# 79998   put_sort  10000  0.130866
# 79999   put_sort  10000  0.134484
#
# [80000 rows x 3 columns]
#             sort      N      T, c
# 0      heap_sort    100  0.000020
# 1      heap_sort    100  0.000018
# 2      heap_sort    100  0.000018
# 3      heap_sort    100  0.000018
# 4      heap_sort    100  0.000018
# ...          ...    ...       ...
# 79995   put_sort  10000  0.135087
# 79996   put_sort  10000  0.133544
# 79997   put_sort  10000  0.139265
# 79998   put_sort  10000  0.139345
# 79999   put_sort  10000  0.146769
#
# [80000 rows x 3 columns]
# Empty DataFrame
# Columns: [sort, N, T, c]
# Index: []

# %%
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots()
sns.lineplot(dat_s,x='N',y='T, c', ax=ax)
sns.lineplot(dat_r,x='N',y='T, c', ax=ax)
sns.lineplot(dat_e,x='N',y='T, c', ax=ax)
# Out:
# <Axes: xlabel='N', ylabel='T, c'>
