# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def getkb(X,Y):
    k=(np.average(Y*X)-np.average(Y)*np.average(X))/(np.average(X*X)-np.average(X)**2)
    b=np.average(Y)-k*np.average(X)
    sigk=np.sqrt(np.abs((np.average(Y*Y)-np.average(Y)*np.average(Y))/(np.average(X*X)-np.average(X)**2) - k*k))/np.sqrt(X.shape[0])
    sigb=sigk*np.sqrt(np.average(X*X)-np.average(X)**2)
    return np.array([k,b,np.abs(sigk/k),np.abs(sigb/b)])

# %%
dt1=pd.read_excel("data.xlsx",sheet_name=0)

# %%
a,b,sa,sb=getkb(dt1.D,dt1.D1)
a,b,sa,sb
# Out:
# (0.027393939393939394,
#  -0.13333333333333286,
#  0.032394699500395044,
#  0.955843273573852)

# %%
fig,ax=plt.subplots()
ax.errorbar(dt1.D,dt1.D1,fmt='.r',yerr=1, label="Измерения")
lp=np.linspace(0,500,10)
ax.plot(lp,lp*a+b,'-',color='black', label="Аппроксимация")
ax.minorticks_on()
ax.grid(which='major')
ax.grid(which='minor', linestyle=':')
ax.set_ylabel(r"Ширина щели на экране, $мм$")
ax.set_xlabel(r"ширина щели, $мкм$")
ax.legend()
fig.savefig("zoom.eps")
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [raw]
# a,b,sa,sb=getkb(dt1.D-12,dt1.D1)
# a,b,sa,sb

# %% [raw]
# fig,ax=plt.subplots()
# ax.errorbar(dt1.D-12,dt1.D1,fmt='.r',yerr=1, label="Измерения")
# lp=np.linspace(0,500,10)
# ax.plot(lp,lp*a+b,'-',color='black', label="Аппроксимация")
# ax.minorticks_on()
# ax.grid(which='major')
# ax.grid(which='minor', linestyle=':')
# ax.set_ylabel(r"Ширина щели на экране, $мм$")
# ax.set_xlabel(r"ширина щели, $мкм$")
# fig.savefig("zoom.eps")

# %%
1290/55
# Out:
# 23.454545454545453

# %%
3.3/0.0234545
# Out:
# 140.69794708904473

# %%
(dt1.D1)/0.0234545
# Out:
# 0     42.635742
# 1     85.271483
# 2    170.542966
# 3    255.814449
# 4    298.450191
# 5    341.085932
# 6    426.357415
# 7    468.993157
# 8    511.628899
# 9    554.264640
# Name: D1, dtype: float64

# %%
b/a
# Out:
# -4.867256637168124

# %%
1290/55, 1/(1/55+1/1290)
# Out:
# (23.454545454545453, 52.750929368029745)

# %%
dt1.D1*1000/23.45
# Out:
# 0     42.643923
# 1     85.287846
# 2    170.575693
# 3    255.863539
# 4    298.507463
# 5    341.151386
# 6    426.439232
# 7    469.083156
# 8    511.727079
# 9    554.371002
# Name: D1, dtype: float64

# %%
532*1340/(11-73)*12/1000
# Out:
# -137.97677419354838
