# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
d=pd.read_excel("data.xlsx")
d
# Out:
#       Tk    p          dP      sigP         r    sr      sigm     ssigm
# 0   19.0  191  232.327127  0.025210  0.000507  0.02  0.058931  0.032180
# 1   19.0  191  232.327127  0.025210  0.000507  0.02  0.058931  0.032180
# 2   26.0  191  232.327127  0.025210  0.000507  0.02  0.058931  0.032180
# 3   26.0  190  230.374798  0.025424  0.000507  0.02  0.058436  0.032348
# 4   26.0  191  232.327127  0.025210  0.000507  0.02  0.058931  0.032180
# 5   29.5  191  232.327127  0.025210  0.000507  0.02  0.058931  0.032180
# 6   29.5  190  230.374798  0.025424  0.000507  0.02  0.058436  0.032348
# 7   29.5  190  230.374798  0.025424  0.000507  0.02  0.058436  0.032348
# 8   34.5  190  230.374798  0.025424  0.000507  0.02  0.058436  0.032348
# 9   34.5  190  230.374798  0.025424  0.000507  0.02  0.058436  0.032348
# 10  34.5  189  228.422469  0.025641  0.000507  0.02  0.057940  0.032519
# 11  39.4  190  230.374798  0.025424  0.000507  0.02  0.058436  0.032348
# 12  39.4  189  228.422469  0.025641  0.000507  0.02  0.057940  0.032519
# 13  39.4  189  228.422469  0.025641  0.000507  0.02  0.057940  0.032519
# 14  44.4  189  228.422469  0.025641  0.000507  0.02  0.057940  0.032519
# 15  44.4  189  228.422469  0.025641  0.000507  0.02  0.057940  0.032519
# 16  44.4  188  226.470141  0.025862  0.000507  0.02  0.057445  0.032693
# 17  49.3  188  226.470141  0.025862  0.000507  0.02  0.057445  0.032693
# 18  49.3  188  226.470141  0.025862  0.000507  0.02  0.057445  0.032693
# 19  49.3  188  226.470141  0.025862  0.000507  0.02  0.057445  0.032693
# 20  54.3  187  224.517812  0.026087  0.000507  0.02  0.056950  0.032871
# 21  54.3  187  224.517812  0.026087  0.000507  0.02  0.056950  0.032871
# 22  54.3  186  222.565483  0.026316  0.000507  0.02  0.056455  0.033053
# 23  59.0  185  220.613154  0.026549  0.000507  0.02  0.055960  0.033239
# 24  59.0  185  220.613154  0.026549  0.000507  0.02  0.055960  0.033239
# 25  59.0  185  220.613154  0.026549  0.000507  0.02  0.055960  0.033239

# %%
def getkb(X,Y):
    k=(np.average(Y*X)-np.average(Y)*np.average(X))/(np.average(X*X)-np.average(X)**2)
    b=np.average(Y)-k*np.average(X)
    def av(n):
        return np.average(n)
    sigk=np.sqrt(np.abs((av(Y*Y)-av(Y)*av(Y))/(av(X*X)-av(X)**2) - k*k))/np.sqrt(X.shape[0])
    #print((av(Y*Y)-av(Y)*av(Y))/(av(X*X)-av(X)**2) - k*k)
    sigb=sigk*np.sqrt(av(X*X)-av(X)**2)
    return k,b,sigk,sigb

# %%
st=sorted(list(set(d.Tk)))
T=np.zeros(len(st))
sigm=np.zeros(len(st))
ssigm=np.zeros(len(st))
k=0
for Tt in st:
    T[k]=np.average(d[d.Tk==Tt].Tk)+273
    sigm[k]=np.average(d[d.Tk==Tt].sigm)
    ssigm[k]=np.average(d[d.Tk==Tt].ssigm)
    k+=1
sigm*=1000
a,b,sa,sb=getkb(T,sigm)
print(a,b,sa,sb)
dsigmdT=np.ones(sigm.shape)*a#np.gradient(sigm,T,edge_order=2)
T=T
sigm=sigm
dsigmdT=dsigmdT
dsigmdT
# Out:
# -0.06988708739866528 79.68766614718265 0.006919912643531898 0.08773864939825375
# array([-0.06988709, -0.06988709, -0.06988709, -0.06988709, -0.06988709,
#        -0.06988709, -0.06988709, -0.06988709, -0.06988709])

# %%
sigm
# Out:
# array([58.93086957, 58.7657971 , 58.60072464, 58.27057971, 58.10550725,
#        57.77536232, 57.44521739, 56.78492754, 55.95956522])

# %%
-T*dsigmdT
# Out:
# array([20.40702952, 20.89623913, 21.14084394, 21.49027938, 21.8327261 ,
#        22.18216154, 22.52460827, 22.87404371, 23.20251302])

# %%
plt.scatter(T,-T*dsigmdT)
plt.scatter(T,sigm)
plt.scatter(T,sigm-T*dsigmdT)

# %%
sigm-T*dsigmdT
# Out:
# array([79.33789909, 79.66203623, 79.74156858, 79.76085909, 79.93823335,
#        79.95752386, 79.96982566, 79.65897124, 79.16207823])

# %%
plt.scatter(T,b+T*a)
plt.scatter(T,sigm)

# %%
UF=np.average(sigm-T*dsigmdT)

# %%
fig,ax=plt.subplots(3,1,figsize=(6,9),constrained_layout=True)

ax[2].errorbar(T,-T*dsigmdT,fmt='.r',yerr=np.abs(sa*T*dsigmdT))
ax[2].plot(T,-T*dsigmdT, 'black', linewidth=1)
ax[2].set_ylim([20,24])
ax[2].spines['top'].set_visible(False)
ax[2].set_xlabel("Температура, $K$")
ax[2].set_ylabel("Коэффициент поверхностного\n"+r"натяжения, $\frac{Дж}{м^2}$")

ax[1].errorbar(T,sigm,fmt='.r',yerr=ssigm*sigm)
ax[1].plot(T,a*T+b, 'black', linewidth=1)
ax[1].set_ylim([55,62])
ax[1].get_xaxis().set_visible(False)
ax[1].spines['top'].set_visible(False)
ax[1].spines['bottom'].set_visible(False)
ax[1].set_ylabel("Теплота образования единицы\n "+r"поверхности жидкости, $\frac{Дж}{м^2}$")


ax[0].errorbar(T,sigm-T*dsigmdT,fmt='.r', yerr=np.sqrt(np.abs(sa*T*dsigmdT)**2+(ssigm*sigm)**2))
ax[0].plot([T[0],T[-1]],[UF,UF], 'black', linewidth=1)
ax[0].set_ylim([75,85])
ax[0].get_xaxis().set_visible(False)
ax[0].spines['bottom'].set_visible(False)
ax[0].set_ylabel("поверхностной энергии $U$\n "+r"единицы площади, $\frac{Дж}{м^2}$")
fig.savefig("res.eps")
